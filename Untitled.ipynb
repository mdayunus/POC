# %%
import pandas as pd
df = pd.read_csv('newBank.csv')
df['count'] = 1
df
# Out:
#            Account No        DATE               TRANSACTION DETAILS  CHQ.NO.  \
# 0       409000611074'  2017-06-29  TRF FROM  Indiaforensic SERVICES      NaN
# 1       409000611074'  2017-07-05  TRF FROM  Indiaforensic SERVICES      NaN
# 2       409000611074'  2017-07-18        FDRL/INTERNAL FUND TRANSFE      NaN
# 3       409000611074'  2017-08-01   TRF FRM  Indiaforensic SERVICES      NaN
# 4       409000611074'  2017-08-16        FDRL/INTERNAL FUND TRANSFE      NaN
# ...               ...         ...                               ...      ...
# 116196  409000362497'  2019-03-05  TRF TO 1196428  Indiaforensic SE      NaN
# 116197  409000362497'  2019-03-05        FDRL/INTERNAL FUND TRANSFE      NaN
# 116198  409000362497'  2019-03-05        FDRL/INTERNAL FUND TRANSFE      NaN
# 116199  409000362497'  2019-03-05                 IMPS 05-03-20194C      NaN
# 116200  409000362497'  2019-03-05         Sweep Trf To: 40900036427      NaN
#
# ...

# %%
fltr = df[['Account No', 'DATE', 'TransactionType', 'TransactionAmount']].duplicated()

# %%
ndf = df.loc[fltr].groupby(['Account No']).sum()
ndf['count'].to_csv('account&count.csv')

# %%
ndf.drop
# Out:
#                   CHQ.NO.  WITHDRAWAL AMT   DEPOSIT AMT  TransactionAmount  \
# Account No
# 1196428'       37321469.0    4.335651e+10  9.387677e+09       5.274418e+10
# 1196711'       97907168.0    3.317726e+10  1.871430e+10       5.189156e+10
# 409000362497'         0.0    1.892308e+08  7.035888e+10       7.054811e+10
# 409000405747'         0.0    1.000000e+07  0.000000e+00       1.000000e+07
# 409000425051'        35.0    1.401250e+03  1.850004e+06       1.851405e+06
# 409000438611'         5.0    5.702001e+08  3.025641e+08       8.727642e+08
# 409000438620'         5.0    1.200788e+09  3.808059e+08       1.581593e+09
# 409000493201'         0.0    0.000000e+00  1.175000e+07       1.175000e+07
# 409000493210'         0.0    4.094436e+07  5.225003e+07       9.319440e+07
# 409000611074'         0.0    5.520000e+03  3.890000e+07       3.890552e+07
#
#                 BALANCE AMT  count
# Account No
# 1196428'      -1.858059e+13  11088
# 1196711'      -6.439182e+12   4399
# ...
